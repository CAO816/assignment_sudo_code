# %%
import google.generativeai as genai
import pathlib
import textwrap

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
genai.configure(api_key="YOUR_API_KEY")

# %%
model = genai.GenerativeModel('gemini-2.5-flash')

# %%
response = model.generate_content("Hà Nội là nơi nào?")

# %%
to_markdown(response.text)
# Out:
# > Hà Nội là thủ đô của nước Cộng hòa Xã hội Chủ nghĩa Việt Nam. Đây là thành phố lớn thứ hai của Việt Nam về dân số, sau Thành phố Hồ Chí Minh. Hà Nội là trung tâm chính trị, văn hóa, giáo dục và kinh tế quan trọng của cả nước.
# >
# > Hà Nội có lịch sử lâu đời, với nhiều di tích lịch sử, văn hóa và kiến trúc độc đáo. Thành phố nổi tiếng với những con phố cổ kính, những hồ nước thơ mộng và những món ăn đặc sản hấp dẫn.

# %%
response = model.generate_content("Tóm tắt đoạn văn sau: Hà Nội là thủ đô của nước Cộng hòa Xã hội Chủ nghĩa Việt Nam. Đây là thành phố lớn thứ hai của Việt Nam về dân số, sau Thành phố Hồ Chí Minh. Hà Nội là trung tâm chính trị, văn hóa, giáo dục và kinh tế quan trọng của cả nước."
+ "Hà Nội có lịch sử lâu đời, với nhiều di tích lịch sử, văn hóa và kiến trúc độc đáo. Thành phố nổi tiếng với những con phố cổ kính, những hồ nước thơ mộng và những món ăn đặc sản hấp dẫn.")
to_markdown(response.text)
# Out:
# > Hà Nội là thủ đô, thành phố lớn thứ hai của Việt Nam, trung tâm chính trị, văn hóa, giáo dục và kinh tế quan trọng. Nơi đây nổi tiếng với lịch sử lâu đời, di tích độc đáo, phố cổ, hồ nước và ẩm thực đặc sắc.
